# %%
import pandas as pd 
import pymongo

#grad_data = pd.read_csv("Admission_Predict_Ver1.1.csv")

kaggle_df = pd.read_csv("Datafiniti_Fast_Food_Restaurants.csv")

#grad_data.rename(columns={"Chance of Admit ":"Chance of Admit"})
kaggle_df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 1  AVwcmSyZIN2L1WUfmxyw  2015-10-19T23:47:58Z  2018-06-26T03:00:14Z
# 2  AVwcopQoByjofQCxgfVa  2016-03-29T05:06:36Z  2018-06-26T02:59:52Z
# 3  AVweXN5RByjofQCxxilK  2017-01-03T07:46:11Z  2018-06-26T02:59:51Z
# 4  AWQ6MUvo3-Khe5l_j3SG  2018-06-26T02:59:43Z  2018-06-26T02:59:43Z
#
#                 address                                    categories  \
# 0      800 N Canal Blvd  American Restaurant and Fast Food Restaurant
# 1      800 N Canal Blvd                         Fast Food Restaurants
# 2   206 Wears Valley Rd                          Fast Food Restaurant
# 3          3652 Parkway                                     Fast Food
# 4  2118 Mt Zion Parkway                          Fast Food Restaurant
#
#            city country                                           keys  \
# 0     Thibodaux      US       us/la/thibodaux/800ncanalblvd/1780593795
# 1     Thibodaux      US       us/la/thibodaux/800ncanalblvd/1780593795
# 2  Pigeon Forge      US  us/tn/pigeonforge/206wearsvalleyrd/-864103396
# 3  Pigeon Forge      US         us/tn/pigeonforge/3652parkway/93075755
# 4        Morrow      US      us/ga/morrow/2118mtzionparkway/1305117222
#
#     latitude  longitude            name postalCode province  \
# 0  29.814697 -90.814742  SONIC Drive In      70301       LA
# 1  29.814697 -90.814742  SONIC Drive In      70301       LA
# 2  35.803788 -83.580553       Taco Bell      37863       TN
# 3  35.782339 -83.551408          Arby's      37863       TN
# 4  33.562738 -84.321143  Steak 'n Shake      30260       GA
#
#                                           sourceURLs  \
# 0  https://foursquare.com/v/sonic-drive-in/4b7361...
# 1  https://foursquare.com/v/sonic-drive-in/4b7361...
# 2  https://www.yellowpages.com/pigeon-forge-tn/mi...
# 3  http://www.yellowbook.com/profile/arbys_163389...
# 4  https://foursquare.com/v/steak-n-shake/4bcf77a...
#
#                                             websites
# 0  https://locations.sonicdrivein.com/la/thibodau...
# 1  https://locations.sonicdrivein.com/la/thibodau...
# 2  http://www.tacobell.com,https://locations.taco...
# 3  http://www.arbys.com,https://locations.arbys.c...
# 4  http://www.steaknshake.com/locations/23851-ste...

# %%
kaggle_df = kaggle_df.drop(columns=['categories', 'keys','sourceURLs', 'websites']).drop_duplicates()
kaggle_df = kaggle_df.loc[kaggle_df['province'].isin(['IL', 'MI', 'IN'])]
kaggle_df.head()
# Out:
#                       id             dateAdded           dateUpdated  \
# 5   AVwc57jLkufWRAb50ROs  2015-10-23T23:59:49Z  2018-06-26T02:59:43Z
# 6   AVwc81QgkufWRAb50vnI  2015-09-21T07:47:08Z  2018-06-26T02:59:43Z
# 19  AVweYSpBByjofQCxxr1V  2015-10-23T02:59:03Z  2018-06-25T09:30:54Z
# 20  AVweGMHhIN2L1WUf184o  2015-10-23T01:26:56Z  2018-06-25T09:30:52Z
# 23  AWIUGMchRxPSIh2Rtd6m  2018-03-11T07:50:51Z  2018-06-25T09:30:50Z
#
#                   address          city country   latitude  longitude  \
# 5    9768 Grand River Ave       Detroit      US  42.368823 -83.138251
# 6    13600 W McNichols Rd       Detroit      US  42.416819 -83.180444
# 19    2860 E Paris Ave SE  Grand Rapids      US  42.911470 -85.568120
# 20   2424 E State Road 44   Shelbyville      US  39.523704 -85.743659
# 23  17620 Grand River Ave       Detroit      US  42.400037 -83.215740
#
#            name postalCode province
# 5       Wendy's      48204       MI
# 6   Burger King      48235       MI
# 19     Checkers      49512       MI
# 20      Rally's      46176       IN
# 23     Checkers      48227       MI

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.fastfood_db

# %%
collection = client.kaggle

# %%
db['kaggle'].drop()
for n in range (0, len(kaggle_df.index)):
    db.kaggle.insert_one(kaggle_df.iloc[n, :].to_dict())
